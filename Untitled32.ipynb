# %% [markdown]
# <a href="https://colab.research.google.com/github/crux007/crux007/blob/main/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/DP_LIVE_15072023004038616.csv')

# %%
df['LOCATION'].unique()
# Out:
# array(['AUS', 'CAN', 'JPN', 'KOR', 'MEX', 'NZL', 'TUR', 'USA', 'ARG',
#        'BRA', 'CHL', 'CHN', 'COL', 'EGY', 'ETH', 'IND', 'IDN', 'IRN',
#        'KAZ', 'MYS', 'NGA', 'PAK', 'PRY', 'PER', 'PHL', 'RUS', 'SAU',
#        'ZAF', 'THA', 'UKR', 'VNM', 'WLD', 'OECD', 'BRICS', 'NOR', 'CHE',
#        'ISR', 'GBR'], dtype=object)

# %%
desired_country = 'GBR'
filtered_df = df[df['LOCATION'] == desired_country]

# %%
print(filtered_df)
# Out:
#       LOCATION  INDICATOR  SUBJECT     MEASURE FREQUENCY  TIME  Value  \
# 18184      GBR  CROPYIELD     RICE  THND_TONNE         A  1990    0.0
# 18185      GBR  CROPYIELD     RICE  THND_TONNE         A  1991    0.0
# 18186      GBR  CROPYIELD     RICE  THND_TONNE         A  1992    0.0
# 18187      GBR  CROPYIELD     RICE  THND_TONNE         A  1993    0.0
# 18188      GBR  CROPYIELD     RICE  THND_TONNE         A  1994    0.0
# ...        ...        ...      ...         ...       ...   ...    ...
# 18671      GBR  CROPYIELD  SOYBEAN     THND_HA         A  2026    0.0
# 18672      GBR  CROPYIELD  SOYBEAN     THND_HA         A  2027    0.0
# 18673      GBR  CROPYIELD  SOYBEAN     THND_HA         A  2028    0.0
# 18674      GBR  CROPYIELD  SOYBEAN     THND_HA         A  2029    0.0
# 18675      GBR  CROPYIELD  SOYBEAN     THND_HA         A  2030    0.0
#
#        Flag Codes
# 18184         NaN
# 18185         NaN
# 18186         NaN
# 18187         NaN
# 18188         NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='TIME', y='Value', hue='SUBJECT', data=filtered_df)
# Out:
# <Axes: xlabel='TIME', ylabel='Value'>

# %%
df_population = pd.read_csv('/content/drive/MyDrive/Pop_Chart1.csv')

# %%
df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Year                                          34 non-null     int64
#  1   UK Population (millions): mid-year estimates  34 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 672.0 bytes

# %%
df_population.head()
# Out:
#    Year  UK Population (millions): mid-year estimates
# 0  1980                                          56.3
# 1  1981                                          56.4
# 2  1982                                          56.3
# 3  1983                                          56.3
# 4  1984                                          56.4

# %%
population_range = df_population[(df_population["Year"] >= 1990) & (df_population["Year"] <= 2022)]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='UK Population (millions): mid-year estimates', data=population_range)
# Out:
# <Axes: xlabel='Year', ylabel='UK Population (millions): mid-year estimates'>
